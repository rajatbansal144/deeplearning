# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatbansal144/deeplearning/blob/main/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/98702494-b71c4e80-237a-11eb-87ed-17fcd6b3f066.jpg">
#
# This is the **official YOLOv5 🚀 notebook** authored by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://www.ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# <img src="https://user-images.githubusercontent.com/26833433/114307955-5c7e4e80-9ae2-11eb-9f50-a90e39bee53f.png" width="900">

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source ../video1.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='../video1.mp4', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-116-gaad99b6 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPS
# video 1/1 (1/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.010s)
# video 1/1 (2/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (3/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (4/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.010s)
# video 1/1 (5/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (6/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (7/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (8/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (9/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (10/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.009s)
# video 1/1 (11/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.009s)
# video 1/1 (12/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.009s)
# video 1/1 (13/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (14/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.010s)
# video 1/1 (15/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (16/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (17/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.011s)
# video 1/1 (18/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (19/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (20/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (21/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (22/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (23/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (24/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.009s)
# video 1/1 (25/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.008s)
# video 1/1 (26/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.008s)
# video 1/1 (27/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (28/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (29/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (30/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (31/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (32/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (33/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (34/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (35/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (36/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (37/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (38/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (39/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (40/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.008s)
# video 1/1 (41/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (42/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (43/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (44/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (45/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (46/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (47/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.011s)
# video 1/1 (48/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (49/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (50/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (51/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (52/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (53/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (54/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (55/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (56/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (57/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.010s)
# video 1/1 (58/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (59/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.008s)
# video 1/1 (60/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.008s)
# video 1/1 (61/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (62/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (63/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (64/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.008s)
# video 1/1 (65/1267) /content/yolov5/../video1.mp4: 384x640 2 fires, Done. (0.007s)
# video 1/1 (66/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (67/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (68/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (69/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (70/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (71/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (72/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (73/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (74/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.008s)
# video 1/1 (75/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (76/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (77/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (78/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (79/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (80/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (81/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (82/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (83/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (84/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (85/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (86/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (87/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (88/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (89/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (90/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (91/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (92/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (93/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (94/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (95/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (96/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (97/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (98/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (99/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (100/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (101/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (102/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (103/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (104/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (105/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (106/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (107/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (108/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (109/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (110/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (111/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (112/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (113/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (114/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (115/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (116/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (117/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (118/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (119/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (120/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.011s)
# video 1/1 (121/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (122/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (123/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (124/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (125/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (126/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (127/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (128/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (129/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.009s)
# video 1/1 (130/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (131/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (132/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (133/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (134/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (135/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.010s)
# video 1/1 (136/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (137/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (138/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (139/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (140/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (141/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (142/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (143/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (144/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (145/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (146/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (147/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (148/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (149/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (150/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (151/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.012s)
# video 1/1 (152/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (153/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (154/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (155/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.007s)
# video 1/1 (156/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (157/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (158/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (159/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (160/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (161/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (162/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (163/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (164/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (165/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (166/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (167/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.009s)
# video 1/1 (168/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (169/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (170/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (171/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (172/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (173/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (174/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (175/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (176/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (177/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (178/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (179/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (180/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (181/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.011s)
# video 1/1 (182/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.011s)
# video 1/1 (183/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (184/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (185/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (186/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (187/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (188/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.013s)
# video 1/1 (189/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.007s)
# video 1/1 (190/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.009s)
# video 1/1 (191/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (192/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.011s)
# video 1/1 (193/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (194/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (195/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 2 smokes, Done. (0.008s)
# video 1/1 (196/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (197/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (198/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (199/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (200/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (201/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.009s)
# video 1/1 (202/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (203/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (204/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 2 smokes, Done. (0.008s)
# video 1/1 (205/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, Done. (0.008s)
# video 1/1 (206/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (207/1267) /content/yolov5/../video1.mp4: 384x640 1 fire, 1 smoke, Done. (0.008s)
# video 1/1 (208/1267) /content/yolov5/../video1.mp4: 384x640 1 fire,
1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1244/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1245/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1246/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1247/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1248/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1249/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1250/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.008s)
# video 1/1 (1251/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.008s)
# video 1/1 (1252/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1253/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1254/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1255/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1256/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1257/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1258/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1259/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1260/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1261/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1262/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1263/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# video 1/1 (1264/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1265/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1266/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.007s)
# video 1/1 (1267/1267) /content/yolov5/../video1.mp4: 384x640 Done. (0.006s)
# Results saved to runs/detect/exp3
# Done. (25.164s)

# %% [markdown]
# # 2. Test
# Test a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python test.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 v5.0-1-g0f395b3 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:05<00:00, 32.3MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients, 218.8 GFLOPS
# val: Scanning '../coco/val2017' images and labels... 4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 3102.29it/s]
# val: New cache created: ../coco/val2017.cache
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 157/157 [01:23<00:00,  1.87it/s]
#                  all        5000       36335       0.745       0.627        0.68        0.49
# Speed: 5.3/1.6/6.9 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/test/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.08s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=90.51s).
# Accumulating evaluation results...
# DONE (t=15.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Results saved to runs/test/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python test.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 80 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/ultralytics/yolov5
#    aad99b6..1f8d716  master     -> origin/master
# github: ⚠️ WARNING: code is out of date by 1 commit. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v5.0-116-gaad99b6 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=2, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='./data/custom_data.yaml', device='', entity=None, epochs=80, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=2, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-05-26 10:50:27.460876: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7066239 parameters, 7066239 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../train_data/labels/train.cache' images and labels... 205 found, 0 missing, 0 empty, 0 corrupted: 100% 205/205 [00:00<00:00, 2499512.56it/s]
# train: Caching images (0.2GB): 100% 205/205 [00:00<00:00, 744.67it/s]
# val: Scanning '../train_data/labels/val.cache' images and labels... 205 found, 0 missing, 0 empty, 0 corrupted: 100% 205/205 [00:00<00:00, 31755.08it/s]
# val: Caching images (0.2GB): 100% 205/205 [00:00<00:00, 758.31it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 4.35, Best Possible Recall (BPR) = 0.9957
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 80 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0
06it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 27.68it/s]
#                  all         205         460       0.966       0.969       0.984       0.642
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      74/79    0.856G   0.03016   0.02757  0.001138   0.05887         3       640: 100% 103/103 [00:06<00:00, 15.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 27.48it/s]
#                  all         205         460       0.978       0.964       0.987       0.638
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      75/79    0.856G   0.02904   0.02744 0.0009105   0.05739         3       640: 100% 103/103 [00:06<00:00, 15.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 27.75it/s]
#                  all         205         460       0.977       0.969       0.983       0.652
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      76/79    0.856G   0.02968   0.02744 0.0009069   0.05803         4       640: 100% 103/103 [00:06<00:00, 15.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 27.15it/s]
#                  all         205         460       0.964       0.975       0.982       0.649
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      77/79    0.856G   0.03073   0.02742  0.001252    0.0594         3       640: 100% 103/103 [00:06<00:00, 14.90it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 27.40it/s]
#                  all         205         460       0.943        0.96       0.976       0.635
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      78/79    0.856G   0.03123   0.02933 0.0007819   0.06135         6       640: 100% 103/103 [00:06<00:00, 14.80it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:01<00:00, 26.57it/s]
#                  all         205         460       0.949       0.964       0.975       0.651
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      79/79    0.856G   0.02999   0.02829 0.0008462   0.05913         2       640: 100% 103/103 [00:06<00:00, 14.84it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 52/52 [00:02<00:00, 22.46it/s]
#                  all         205         460       0.953       0.962       0.978       0.661
#                 fire         205         239       0.953       0.992       0.994       0.676
#                smoke         205         221       0.954       0.932       0.962       0.646
# 80 epochs completed in 0.202 hours.
#
# Optimizer stripped from runs/train/exp2/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 14.4MB

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/98184457-bd3da580-1f0a-11eb-8461-95d908a71893.jpg" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # test batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/83667642-90fcb200-a583-11ea-8fa3-338bbf7da194.jpeg" width="750">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667626-8c37fe00-a583-11ea-997b-0923fe59b29b.jpeg" width="750">
# `test_batch0_labels.jpg` shows test batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667635-90641b80-a583-11ea-8075-606316cebb9c.jpeg" width="750">
# `test_batch0_pred.jpg` shows test batch 0 _predictions_

# %% [markdown]
# Training losses and performance metrics are also logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and a custom `results.txt` logfile which is plotted as `results.png` (below) after training completes. Here we show YOLOv5s trained on COCO128 to 300 epochs, starting from scratch (blue), and from pretrained `--weights yolov5s.pt` (orange).

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/97808309-8182b180-1c66-11eb-8461-bffe1a79511d.png" width="800">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([test.py](https://github.com/ultralytics/yolov5/blob/master/test.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/models/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Re-clone repo
# %cd ..
# %rm -rf yolov5 && git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python test.py --weights $m.pt --device $d # test official
    python test.py --weights runs/train/exp/weights/best.pt --device $d # test custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python models/export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data voc.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
